# %% [markdown]
# #####  Homework 1 due to 9.25
# - trackbar, color channel, text, box selection

# %%
import cv2
import numpy as np

# %%
org_img = cv2.imread('mountain.jpg')
img = org_img.copy()

# %%
def nothing(x):
    pass

# %%
drawing = False # true if mouse is pressed
mode = True # if True, draw rectangle. Press 'm' to toggle to curve
ix,iy = -1,-1

# mouse callback function
def draw_circle(event,x,y,flags,param):
    global ix,iy,drawing,mode,img

    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix,iy = x,y

    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing == True:
            if mode == True:
                 cv2.rectangle(img,(ix,iy),(x,y),(0,0,255),-1)
            else:
                cv2.circle(img,(x,y),5,(0,0,255),-1)
    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        if mode == True:
            cv2.rectangle(img,(ix,iy),(x,y),(0,0,255),-1)
        else:
            cv2.circle(img,(x,y),5,(0,0,255),-1)

# %%
org_img = cv2.imread('homework.jpg')
cv2.namedWindow('image')
cv2.createTrackbar('value','image',0,255,nothing)
font = cv2.FONT_HERSHEY_SIMPLEX
while(1):
    img = org_img.copy()
    value = cv2.getTrackbarPos('value','image')
    cv2.putText(img,f"Mouse position : {value}",(30,70), font, 2,(255,255,255),2,cv2.LINE_AA)
    cv2.imshow('image',img)
    k = cv2.waitKey(1) & 0xFF
    if k == 27: #이게 ese인듯
        break
cv2.destroyAllWindows()

# %%
cv2.namedWindow('mountain', cv2.WINDOW_NORMAL)
cv2.imshow('mountain',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
